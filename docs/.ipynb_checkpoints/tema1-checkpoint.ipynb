# %% [markdown]
# # Tema 1: Molekylvisualisering

# %% [markdown]
# ## 1. Hypotese
# Her gjetter vi på noe greier.
#
# ## 2. Teori
# Spektroskopi er gøy.

# %%
import numpy as np
import matplotlib.pyplot as plt

P = np.array([1, 2, 3, 4, 5, 6, 7])

R = 8.31 # Gasskonstanten
T = 298  # Temp. i K
n = 1    # Stoffmengde i mol

V = n*R*T/P

plt.plot(P,V,color='hotpink',marker='o',linestyle='')
plt.show()

# %% [markdown]
# Vi kan skrive matematikk og reaksjonslikninger med LaTeX:
#
# $$2H_2 (g) + O_2 (g) \rightarrow 2H_2O (l)$$
#
# $$\int_0^1 e^{2x} dx$$

# %%
import py3Dmol

testosteron = py3Dmol.view(query='cid:6013')
testosteron.setStyle({'stick':{'color':'spectrum'}})
# Out:
# <div id="3dmolviewer_1602503251068562"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1602503251068562" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1602503251068562 = null;
# var warn = document.getElementById("3dmolwarning_1602503251068562");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1602503251068562 = $3Dmol.createViewer($("#3dmolviewer_1602503251068562"),{backgroundColor:"white"});
# $3Dmol.download("cid:6013", viewer_1602503251068562, {}, function() {
# 	viewer_1602503251068562.setStyle({"stick": {"color": "spectrum"}});
# viewer_1602503251068562.render();
# })
# });
# </script>

# %%
bromelain = py3Dmol.view(query='pdb:6B7N')
bromelain.setStyle({'cartoon':{'color':'spectrum'}})
# Out:
# <div id="3dmolviewer_160250326521577"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_160250326521577" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_160250326521577 = null;
# var warn = document.getElementById("3dmolwarning_160250326521577");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_160250326521577 = $3Dmol.createViewer($("#3dmolviewer_160250326521577"),{backgroundColor:"white"});
# $3Dmol.download("pdb:6B7N", viewer_160250326521577, {}, function() {
# 	viewer_160250326521577.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_160250326521577.render();
# })
# });
# </script>
